# %% [markdown]
# # Multimodal Librarian Development Playground
#
# This notebook can be used for development experimentation and testing.

# %%
# Import the application modules
import sys
sys.path.append('/app/src')

# Example: Test database connections
from multimodal_librarian.config.config_factory import get_database_config
from multimodal_librarian.clients.database_factory import DatabaseClientFactory

config = get_database_config()
factory = DatabaseClientFactory(config)

print(f"Database type: {config.database_type}")
print(f"Environment: {config.ml_environment}")
